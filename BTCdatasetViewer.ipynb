# %%
import pandas as pd
import pandas_datareader as pdr
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
#from datetime import datetime
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, plot_mpl, offline
# %matplotlib inline
# Out:
# c:\program files\python38\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
dfSPY=pdr.data.DataReader("SPY", 
                       start='1985-1-1', 
                       end='2020-4-12', 
                       data_source='yahoo')
dfSPY.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 1993-01-29  43.96875  43.75000  43.96875  43.93750  1003200.0  26.299288
# 1993-02-01  44.25000  43.96875  43.96875  44.25000   480500.0  26.486324
# 1993-02-02  44.37500  44.12500  44.21875  44.34375   201300.0  26.542448
# 1993-02-03  44.84375  44.37500  44.40625  44.81250   529400.0  26.822998
# 1993-02-04  45.09375  44.46875  44.96875  45.00000   531500.0  26.935240

# %%
df=pd.read_csv('btc--2014-9-26-to-2020-4-15.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2036 entries, 0 to 2035
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2036 non-null   object
#  1   High       2036 non-null   float64
#  2   Low        2036 non-null   float64
#  3   Open       2036 non-null   float64
#  4   Close      2036 non-null   float64
#  5   Volume     2036 non-null   int64
#  6   Adj Close  2036 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 111.5+ KB

# %%
print(df['Low'][2000])
# Out:
# 7690.09814453125

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'], open=df['Open'][900:], high=df['High'][900:], low=df['Low'][900:], close=df['Close'][900:])])

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="292a8745-9c8c-4da1-96fb-0533c1da06e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("292a8745-9c8c-4da1-96fb-0533c1da06e4")) {
#                     Plotly.newPlot(
#                         '292a8745-9c8c-4da1-96fb-0533c1da06e4',
# ...

# %%
dfSPY.to_csv('spy.csv')

# %%
dfBTC=pdr.data.DataReader("BTC-USD", 
                       start='2011-1-1', 
                       end='2020-4-13', 
                       data_source='google')
dfBTC.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-e84c0fc769e2> in <module>
# ----> 1 dfBTC=pdr.data.DataReader("BTC-USD", granularity=240*60,
#       2                        start='2011-1-1',
#       3                        end='2020-4-13',
#       4                        data_source='google')
#       5 dfBTC.head()
#
# c:\program files\python38\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# TypeError: DataReader() got an unexpected keyword argument 'granularity'

# %%
dfBTC.to_csv('btc--2014-9-26-to-2020-4-13.csv')

# %%
datetime.datetime()
